# %% [markdown]
# # Pandas DataFrame

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
myDataFrame = pd.read_csv('AAPL-2017.csv',usecols=['Date','Volume'])
myDataFrame.plot()
plt.show()
